# %%
import tkinter as tk
from tkinter import filedialog
from tkinter import *
from PIL import ImageTk, Image

import numpy as np 
import pandas as pd 
import tensorflow as tf
from PIL import Image
import os
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
import numpy

#load the trained model to classify sign
from keras.models import load_model
model = load_model('traffic_classifier.h5')

#dictionary to label all traffic signs class.
classes = { 1 : "Limite de vitesse (20 km/h)",
            2 : "Limite de vitesse (30 km/h)",
            3 : "Limite de vitesse (50 km/h)",
            4 : "Limite de vitesse (60 km/h)",
            5 : "Limite de vitesse (70 km/h)",
            6 : "Limite de vitesse (80 km/h)",
            7 : "Fin de limite de vitesse (80 km/h)",
            8 : "Limite de vitesse (100 km/h)",
            9 : "Limite de vitesse (120 km/h)",
            10 : "Interdiction de dépasser",
            11 : "Interdiction de dépasser les véhicules de plus de 3,5 tonnes",
            12 : "Priorité à droite à une intersection",
            13 : "Route prioritaire",
            14 : "Cédez le passage",
            15 : "Stop",
            16 : "Interdiction de circuler",
            17 : "Interdiction de circuler pour les véhicules de plus de 3,5 tonnes",
            18 : "Interdiction d'entrer",
            19 : "Danger",
            20 : "Virage dangereux à gauche",
            21 : "Virage dangereux à droite",
            22 : "Double virage",
            23 : "Route bosselée",
            24 : "Route glissante",
            25 : "Rétrécissement de la chaussée à droite",
            26 : "Travaux",
            27 : "Feux de signalisation",
            28 : "Passage piéton",
            29 : "Passage d'enfants",
            30 : "Passage de cyclistes",
            31 : "Attention verglas/neige",
            32 : "Passage d'animaux sauvages",
            33 : "Fin de limitation de vitesse et d'interdiction de dépasser",
            34 : "Tourner à droite",
            35 : "Tourner à gauche",
            36 : "Tout droit uniquement",
            37 : "Tout droit ou à droite",
            38 : "Tout droit ou à gauche",
            39 : "Obligation de tourner à droite",
            40 : "Obligation de tourner à gauche",
            41 : "Rond-point obligatoire",
            42 : "Fin de l'interdiction de dépasser",
            43 : "Fin de l'interdiction de dépasser les véhicules de plus de 3,5 tonnes" }
                 
#initialise GUI
top=tk.Tk()
top.geometry('1000x600')
top.title('Reconnaissance des panneaux de signalisation')
top.configure(background='#CDCDCD')

label=Label(top,background='#CDCDCD', font=('arial',15,'bold'))
sign_image = Label(top)

def classify(file_path):
    global label_packed
    image = Image.open(file_path)    
    image = image.resize((30,30))
    image = numpy.expand_dims(image, axis=0)
    image = numpy.array(image)
    
    print(image.shape)
    print(type(image))
    pred = model.predict_classes([image])[0]
    sign = classes[pred+1]
    print(sign)
    label.configure(foreground='#011638', text=sign) 
   

def show_classify_button(file_path):
    classify_b=Button(top,text="Classier l'image",command=lambda: classify(file_path),padx=10,pady=5)
    classify_b.configure(background='#364156', foreground='white',font=('arial',10,'bold'))
    #classify_b.pack(side=BOTTOM,pady=20)
    classify_b.place(relx=0.79,rely=0.46)

def upload_image():
    try:
        file_path=filedialog.askopenfilename()
        uploaded=Image.open(file_path)
        uploaded.thumbnail(((top.winfo_width()/2.25),(top.winfo_height()/2.25)))
        im=ImageTk.PhotoImage(uploaded)
        
        sign_image.configure(image=im)
        sign_image.image=im
        label.configure(text='')
        print(type(uploaded))
        show_classify_button(file_path)
    except:
        pass

upload=Button(top,text="Importer image",command=upload_image,padx=10,pady=5)
upload.configure(background='#364156', foreground='white',font=('arial',10,'bold'))

upload.pack(side=BOTTOM,pady=50)
sign_image.pack(side=BOTTOM,expand=True)
label.pack(side=BOTTOM,expand=True)
heading = Label(top, text="Reconnaissance des panneaux de signalisation par DeepLearning",pady=20, font=('arial',20,'bold'))
heading.configure(background='#CDCDCD',foreground='#364156')
heading.pack()
top.mainloop()
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# (1, 30, 30, 4)
# <class 'numpy.ndarray'>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\sabri\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-7-3e160a2dc0ba>", line 90, in <lambda>
#     classify_b=Button(top,text="Classier l'image",command=lambda: classify(file_path),padx=10,pady=5)
#   File "<ipython-input-7-3e160a2dc0ba>", line 83, in classify
#     pred = model.predict_classes([image])[0]
#   File "c:\Users\sabri\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "c:\Users\sabri\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py", line 453, in predict_classes
#     proba = self.predict(x, batch_size=batch_size, verbose=verbose)
# ...

# %% [markdown]
# type()
